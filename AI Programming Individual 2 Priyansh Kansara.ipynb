# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("sonar data.csv", header = None)

data.head(5)
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
data.shape
# Out:
# (208, 61)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
data.isna().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %% [markdown]
# # Machine Learning models

# %%
X = data.drop(columns=60, axis=1)
Y = data[60]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.2, random_state = 1)

# %%
X_train.shape
# Out:
# (166, 60)

# %%
X_test.shape
# Out:
# (42, 60)

# %%
X_test
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 186  0.0209  0.0191  0.0411  0.0321  0.0698  0.1579  0.1438  0.1402  0.3048
# 155  0.0211  0.0128  0.0015  0.0450  0.0711  0.1563  0.1518  0.1206  0.1666
# 165  0.0221  0.0065  0.0164  0.0487  0.0519  0.0849  0.0812  0.1833  0.2228
# 200  0.0131  0.0387  0.0329  0.0078  0.0721  0.1341  0.1626  0.1902  0.2610
# 58   0.0225  0.0019  0.0075  0.0097  0.0445  0.0906  0.0889  0.0655  0.1624
# 34   0.0311  0.0491  0.0692  0.0831  0.0079  0.0200  0.0981  0.1016  0.2025
# 151  0.0231  0.0315  0.0170  0.0226  0.0410  0.0116  0.0223  0.0805  0.2365
# 18   0.0270  0.0092  0.0145  0.0278  0.0412  0.0757  0.1026  0.1138  0.0794
# 202  0.0272  0.0378  0.0488  0.0848  0.1127  0.1103  0.1349  0.2337  0.3113
# 62   0.0086  0.0215  0.0242  0.0445  0.0667  0.0771  0.0499  0.0906  0.1229
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ...

# %%
from sklearn.preprocessing import StandardScaler as ss
sc = ss()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(kernel = 'rbf')
model_svm.fit(X_train,y_train)
y_pred_svm = model_svm.predict(X_test)
y_pred_svm
# Out:
# array(['M', 'R', 'M', 'M', 'R', 'R', 'R', 'R', 'M', 'R', 'M', 'R', 'M',
#        'M', 'M', 'M', 'R', 'M', 'M', 'R', 'M', 'R', 'M', 'R', 'M', 'M',
#        'M', 'M', 'R', 'M', 'R', 'M', 'R', 'M', 'R', 'R', 'R', 'R', 'R',
#        'M', 'M', 'M'], dtype=object)

# %%
from sklearn.tree import DecisionTreeClassifier
model_decision_tree = DecisionTreeClassifier()
model_decision_tree.fit(X_train,y_train)
y_pred_decision_tree = model_decision_tree.predict(X_test)
y_pred_decision_tree
# Out:
# array(['R', 'M', 'R', 'R', 'R', 'R', 'M', 'R', 'M', 'R', 'M', 'R', 'R',
#        'R', 'M', 'M', 'R', 'M', 'M', 'R', 'M', 'R', 'R', 'R', 'M', 'M',
#        'R', 'M', 'R', 'M', 'M', 'M', 'M', 'R', 'M', 'M', 'R', 'R', 'R',
#        'M', 'M', 'M'], dtype=object)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LogisticRegression
model_logistic_regression = LogisticRegression()
model_logistic_regression.fit(X_train,y_train)
y_pred_decision_logistic_regression = model_logistic_regression.predict(X_test)
y_pred_decision_logistic_regression
# Out:
# array(['M', 'M', 'M', 'M', 'R', 'R', 'M', 'R', 'M', 'R', 'M', 'M', 'M',
#        'M', 'R', 'M', 'R', 'M', 'M', 'R', 'M', 'R', 'M', 'M', 'M', 'M',
#        'M', 'M', 'R', 'M', 'R', 'M', 'R', 'R', 'R', 'R', 'R', 'M', 'R',
#        'M', 'M', 'M'], dtype=object)

# %%
from sklearn.metrics import accuracy_score

# %%
training_data_accuracy_svm = accuracy_score(y_pred_svm, y_test) 
print(training_data_accuracy_svm)
# Out:
# 0.7857142857142857

# %%
training_data_accuracy_decision_tree = accuracy_score(y_pred_decision_tree, y_test) 
print(training_data_accuracy_decision_tree)
# Out:
# 0.7380952380952381

# %%
training_data_accuracy_logistic_regression = accuracy_score(y_pred_decision_logistic_regression, y_test) 
print(training_data_accuracy_logistic_regression)
# Out:
# 0.7619047619047619
